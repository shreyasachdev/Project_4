# %%
# !pip install boto3
# Out:
# ...
#   Using cached s3transfer-0.3.3-py2.py3-none-any.whl (69 kB)
# ...
#   Using cached jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# ...
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.16
#     Uninstalling docutils-0.16:
#       Successfully uninstalled docutils-0.16
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import boto3
from io import BytesIO

# %%
s3 = boto3.resource('s3', region_name='us-east-2')
bucket = s3.Bucket('car-image')
object = bucket.Object('Honda_Civic_2012_16_15_140_18_4_69_55_176_nan_FWD_5_2_2dr_oYh.jpg')
tmp = tempfile.NamedTemporaryFile()

# %%
resource = boto3.resource('s3', region_name='us-east-2')
bucket = resource.Bucket('car-image')

image_object = bucket.Object('Honda_Civic_2012_16_15_140_18_4_69_55_176_nan_FWD_5_2_2dr_oYh.jpg')
image = mpimg.imread(BytesIO(image_object.get()['Body'].read()), 'jpg')

plt.figure(0)
plt.imshow(image);
